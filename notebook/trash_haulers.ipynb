# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import datetime

# %%
trash_haulers= pd.read_csv('../data/trash_hauler_report.csv')
trash_haulers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20226 entries, 0 to 20225
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    20226 non-null  int64
#  1   Date Opened       20226 non-null  object
#  2   Request           20226 non-null  object
#  3   Description       20195 non-null  object
#  4   Incident Address  20217 non-null  object
#  5   Zip Code          20151 non-null  float64
#  6   Trash Hauler      19325 non-null  object
#  7   Trash Route       19279 non-null  object
#  8   Council District  20177 non-null  float64
#  9   State Plan X      20198 non-null  float64
#  10  State Plan Y      20198 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1.7+ MB

# %%
trash_haulers.nunique()
# Out:
# Request Number      20226
# Date Opened           686
# Request                 4
# Description         12879
# Incident Address    14121
# Zip Code               28
# Trash Hauler            4
# Trash Route           173
# Council District       35
# State Plan X        14243
# State Plan Y        14322
# dtype: int64

# %%
trash_haulers
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_haul = trash_haulers.drop(columns = ['State Plan X','State Plan Y'])
trash_haul
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_haul['Date Opened'] = pd.to_datetime(trash_haul['Date Opened'], format ='%m/%d/%y')

# %%
#trash_haul['Zip Code'] = trash_haul['Zip Code'].astype('str')
trash_haul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20226 entries, 0 to 20225
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    20226 non-null  int64
#  1   Date Opened       20226 non-null  datetime64[ns]
#  2   Request           20226 non-null  object
#  3   Description       20195 non-null  object
#  4   Incident Address  20217 non-null  object
#  5   Zip Code          20151 non-null  float64
#  6   Trash Hauler      19325 non-null  object
#  7   Trash Route       19279 non-null  object
#  8   Council District  20177 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 1.4+ MB

# %%
#trash_haul['Zip Code'] = trash_haul['Zip Code'].str.strip('.0')
trash_haul
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270  2017-11-01                      Trash - Backdoor
# 1               25274  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 2               25276  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 3               25307  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 4               25312  2017-11-01  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20222          267126  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20223          267130  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20224          267134  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20225          267137  2019-11-01  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_haul['Trash Hauler'].value_counts()
# Out:
# Trash Hauler
# RED RIVER    14395
# METRO         3512
# WASTE IND     1350
# Metro           68
# Name: count, dtype: int64

# %%
trash_haul['Trash Hauler'] = trash_haul['Trash Hauler'].str.upper()
trash_haul['Trash Hauler'].value_counts()
# Out:
# Trash Hauler
# RED RIVER    14395
# METRO         3580
# WASTE IND     1350
# Name: count, dtype: int64

# %%
trash_haul
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270  2017-11-01                      Trash - Backdoor
# 1               25274  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 2               25276  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 3               25307  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 4               25312  2017-11-01  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20222          267126  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20223          267130  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20224          267134  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20225          267137  2019-11-01  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_haul["Incident Address"] = trash_haul["Incident Address"].str.title()
trash_haul
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270  2017-11-01                      Trash - Backdoor
# 1               25274  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 2               25276  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 3               25307  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 4               25312  2017-11-01  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20222          267126  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20223          267130  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20224          267134  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20225          267137  2019-11-01  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_haul.loc[trash_haul['Zip Code']== 'nan']
# Out:
# Empty DataFrame
# Columns: [Request Number, Date Opened, Request , Description, Incident Address, Zip Code, Trash Hauler, Trash Route, Council District]
# Index: []

# %%
trash_haul[['Street Address' , 'Other']] = trash_haul['Incident Address'].str.split(',', n=1, expand=True)
trash_haul
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270  2017-11-01                      Trash - Backdoor
# 1               25274  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 2               25276  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 3               25307  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 4               25312  2017-11-01  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20222          267126  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20223          267130  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20224          267134  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20225          267137  2019-11-01  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_haul[['Zip']] = trash_haul['Other'].str.extract(r'(\d{5})')
trash_haul
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270  2017-11-01                      Trash - Backdoor
# 1               25274  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 2               25276  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 3               25307  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 4               25312  2017-11-01  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20222          267126  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20223          267130  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20224          267134  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20225          267137  2019-11-01  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_haul['Zip Code'] = trash_haul['Zip Code'].fillna(trash_haul['Zip'])
trash_haul
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270  2017-11-01                      Trash - Backdoor
# 1               25274  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 2               25276  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 3               25307  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 4               25312  2017-11-01  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20222          267126  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20223          267130  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20224          267134  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20225          267137  2019-11-01  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_haul['Zip Code'] = trash_haul['Zip Code'].astype('str')

# %%
trash_haul['Zip Code'] = trash_haul['Zip Code'].str.strip('.0')
trash_haul
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270  2017-11-01                      Trash - Backdoor
# 1               25274  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 2               25276  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 3               25307  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 4               25312  2017-11-01  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20222          267126  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20223          267130  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20224          267134  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20225          267137  2019-11-01  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_haul['Zip Code'].value_counts()
# Out:
# Zip Code
# 37013    2283
# 37211    2249
# 37205    1492
# 37209    1413
# 37215    1405
# 37207    1302
# 37115    1271
# 37206    1218
# 37208    1041
# 37214    1005
# 37218     983
# 37216     843
# 37217     834
# 37204     635
# 37212     602
# 3721      551
# 37203     395
# 3722      289
# 37027     170
# 37189      60
# 37221      48
# 37219      42
# nan        40
# 37201      35
# 37138       5
# 37076       5
# 37086       3
# 37213       1
# 37188       1
# 37174       1
# 37066       1
# 37228       1
# 30004       1
# 37129       1
# Name: count, dtype: int64

# %%
trash_haul['Incident Address'].isnull().sum()
# Out:
# 9

# %%
trash_haul = trash_haul.dropna(subset= 'Incident Address')

# %%
trash_haul
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270  2017-11-01                      Trash - Backdoor
# 1               25274  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 2               25276  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 3               25307  2017-11-01  Trash - Curbside/Alley Missed Pickup
# 4               25312  2017-11-01  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20222          267126  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20223          267130  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20224          267134  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 20225          267137  2019-11-01  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_haul['Incident Address'].isna().sum()
# Out:
# 0
